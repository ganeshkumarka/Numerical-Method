# %% [markdown]
# <a href="https://colab.research.google.com/github/ganeshkumarka/Numerical-Method/blob/main/Lab_woks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# def bisect(f,a,b,root,k)
# {
#       c = (a+b)/2
#       if(b-c)<=k:


# }
# a = 2
# b = 3
# prev_cn = 0  # Initialize prev_cn for the first iteration

# for iteration in range(1, 500):
#     cn = (a + b) / 2
#     fn = cn**3 - 4*cn - 9

#     print(f"Iteration {iteration}:")
#     print(f"  cn: {cn}")
#     print(f"  fn: {fn}")
#     print(f"  a: {a}")
#     print(f"  b: {b}")

#     if fn > 0:
#         b = cn
#     else:
#         a = cn

#     # Check the difference and break the loop if it's within the specified range
#     if abs(cn - prev_cn) <= 0.00005:
#         break

#     prev_cn = cn

def fun(j):
  f=j**3-(4*j)-9;
  return f;

def bisection(t):
  i=0
  j=0
  while(fun(j)*fun(j+1)>0):
    j=j+1
    a=j
    b=j+1
    print("a : ",a)
    print("b : ",b)
    c=(a+b)/2
  while((b-c)>t):
    f=fun(c)
    if f<0:
      a=c
    elif f>0
      b=c
    c=(a+b)/2
    i=i+1
    print("Iteration: ",i)
    print("a : ",a)
    print("b : ",b)
    print("c : ",c)
  print("root : ",c)

bisection(0.00005)

"""
    Newton-Raphson method for finding the root of a function.

    Parameters:
    - f: The function for which we want to find the root.
    - df: The derivative of the function f.
    - x0: Initial guess for the root.
    - tol: Tolerance (convergence criterion).
    - max_iter: Maximum number of iterations.

    Returns:
    - root: The approximated root.
    - num_iter: The number of iterations performed.
    """

def newton_raphson(f, df, x0, tol=1e-6, max_iter=100):

    x = x0
    for i in range(max_iter):
        x_new = x - f(x) / df(x)

        if abs(x_new - x) < tol:
            return x_new, i+1  # Return the root and the number of iterations

        x = x_new

    raise ValueError("Newton-Raphson method did not converge within the maximum number of iterations.")

# Example usage:
if __name__ == "__main__":
    # Define the function and its derivative
    def my_function(x):
        return x**2 - 4

    def my_function_derivative(x):
        return 2 * x

    # Initial guess
    x0 = 2.0

    # Apply Newton-Raphson method
    root, num_iter = newton_raphson(my_function, my_function_derivative, x0)

    print(f"Approximated root: {root}")
    print(f"Number of iterations: {num_iter}")
# Out:
#   File "<ipython-input-1-236506c0701c>", line 51
#     elif f>0
#             ^
# SyntaxError: expected ':'

# %%
def bisect(function : str, a : int, b : int, Epsilon : float) -> float :
    if function(a) * function(b) >= 0:
        return None
    c = None
    while ((b-a) >= Epsilon):
        c = (a + b) / 2
        if function(c) == 0.0:
            break
        if function(c) * function(a) < 0:
            b = c
        else:
            a = c
    return c


def main():
    function = input("Enter the function in terms of x: ")
    a = int(input("Enter the value of a: "))
    b = int(input("Enter the value of b: "))
    Epsilon = float(input("Enter the value of ε: "))
    func = lambda x: eval(function)
    root = bisect(func, a, b, Epsilon)
    if root is not None:
        print("The value of root is : ", "%.4f"%root)
    else:
        print("Can't find root in given interval")

if __name__ == "__main__":
    main()
# Out:
# Enter the function in terms of x: x**3-4*x-9
# Enter the value of a: 2
# Enter the value of b: 3
# Enter the value of ε: 0.00005
# The value of root is :  2.7065

# %%
#regular falsi or false position method
def regular_falsi(function : str, a : int, b : int, Epsilon : float) -> float :
    if function(a) * function(b) >= 0:
        return None
    c = None
    while ((b-a) >= Epsilon):
        c = (a*function(b)-b*function(a))/function(b)-function(a)
        if function(c) == 0.0:
            break
        if function(c) * function(a) < 0:
            b = c
        else:
            a = c
    return c


def main():
    function = input("Enter the function in terms of x: ")
    a = int(input("Enter the value of a: "))
    b = int(input("Enter the value of b: "))
    Epsilon = float(input("Enter the value of ε: "))
    func = lambda x: eval(function)
    root = bisect(func, a, b, Epsilon)
    if root is not None:
        print("The value of root is : ", "%.4f"%root)
    else:
        print("Can't find root in given interval")

if __name__ == "__main__":
    main()
# Out:
# Enter the function in terms of x: x**3-4*x-9
# Enter the value of a: 2
# Enter the value of b: 3
# Enter the value of ε: 0.00005
# The value of root is :  2.7065

# %%
#newton raphson method

def newton_raphson(f, df, x0, tol=1e-6, max_iter=100):
   x=x0
   for i in range(max_iter):
        x_new = x - f(x) / df(x)

        if abs(x_new - x) < tol:
            return x_new, i+1

        x = x_new

if __name__ == "__main__":

    def f(x):
        #return x**2 - 4
        return x**6-x-1

    def df(x):
        return 6*x**5-1

    x0 = 2.0
    root,num_iter = newton_raphson(f,df,x0)
    print(root)
    print(num_iter)
# Out:
# 1.1347241384015194
# 8
